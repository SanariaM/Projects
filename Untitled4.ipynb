# %% [markdown]
# <a href="https://colab.research.google.com/github/SanariaM/Projects/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's Import the **modules**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('modules are imported.')
# Out:
# modules are imported.

# %% [markdown]
# **Task 2.1:importing covid19 dataset**

# %% [markdown]
# Importing "Covid19_Confirmed_dataset csv" from"./Dataset"folder

# %%
corona_dataset_csv = pd.read_csv("https://covidtracking.com/data/download/all-states-history.csv")
corona_dataset_csv.head(10)
# Out:
#          date state  ...  totalTestsViral  totalTestsViralIncrease
# 0  2021-03-07    AK  ...        1731628.0                        0
# 1  2021-03-07    AL  ...              NaN                        0
# 2  2021-03-07    AR  ...        2736442.0                     3380
# 3  2021-03-07    AS  ...           2140.0                        0
# 4  2021-03-07    AZ  ...        7908105.0                    45110
# 5  2021-03-07    CA  ...       49646014.0                   133186
# 6  2021-03-07    CO  ...              NaN                        0
# 7  2021-03-07    CT  ...        6520366.0                        0
# 8  2021-03-07    DC  ...              NaN                        0
# 9  2021-03-07    DE  ...              NaN                        0
#
# [10 rows x 41 columns]

# %% [markdown]
# **Lets check the shape of the dataframe.**

# %%
corona_dataset_csv.shape
# Out:
# (20780, 41)

# %% [markdown]
# Task 2.2:Delete the useless columns

# %%
corona_dataset_csv.drop(["totalTestResultsIncrease",	"totalTestsAntibody",	"totalTestsAntigen",	
                         "totalTestsPeopleAntibody",	"totalTestsPeopleAntigen",	"totalTestsPeopleViral",	
                         "totalTestsPeopleViralIncrease",	"totalTestsViral",	"totalTestsViralIncrease", "inIcuCumulative",	"inIcuCurrently",
                         "negative","negativeIncrease",	"negativeTestsAntibody","negativeTestsPeopleAntibody",	"negativeTestsViral",	
                         "onVentilatorCumulative",	"onVentilatorCurrently"],axis=1,inplace=True)
corona_dataset_csv.head(10)
# Out:
#          date state  ...  totalTestEncountersViralIncrease  totalTestResults
# 0  2021-03-07    AK  ...                                 0         1731628.0
# 1  2021-03-07    AL  ...                                 0         2323788.0
# 2  2021-03-07    AR  ...                                 0         2736442.0
# 3  2021-03-07    AS  ...                                 0            2140.0
# 4  2021-03-07    AZ  ...                                 0         7908105.0
# 5  2021-03-07    CA  ...                                 0        49646014.0
# 6  2021-03-07    CO  ...                             38163         6415123.0
# 7  2021-03-07    CT  ...                                 0         6520366.0
# 8  2021-03-07    DC  ...                              5726         1261363.0
# 9  2021-03-07    DE  ...                              5867         1431942.0
#
# [10 rows x 23 columns]

# %% [markdown]
# **Task 2.3:Aggregating the rows by the state**

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("state").sum()
corona_dataset_aggregated.head(10)
# Out:
#            death  ...  totalTestResults
# state             ...
# AK       31486.0  ...      2.082177e+08
# AL     1038264.0  ...      3.662777e+08
# AR      601561.0  ...      3.685376e+08
# AS           0.0  ...      4.445310e+05
# AZ     1918434.0  ...      9.190266e+08
# CA     5733089.0  ...      5.833385e+09
# CO      908462.0  ...      7.034087e+08
# CT     1584666.0  ...      7.782720e+08
# DC      207067.0  ...      1.546670e+08
# DE      228375.0  ...      1.745888e+08
#
# [10 rows x 21 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (56, 21)

# %% [markdown]
# **Task 2.4: Visualizing data related to a state for exmple CA**

# %% [markdown]
# visuallization always helps for better understanding of our data.

# %%
corona_dataset_aggregated.loc["CA"].plot()
corona_dataset_aggregated.loc["NY"].plot()
corona_dataset_aggregated.loc["NJ"].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc["NY"][:5].plot()

# %% [markdown]
# Task 3.1: caculating and plotting the first derivative of the curve

# %%
corona_dataset_aggregated.loc["NY"].diff().plot()

# %% [markdown]
# **Task 3.2: find maximum infection rate for NY, CA and NJ**

# %%
corona_dataset_aggregated.loc["NY"].diff().max()
# Out:
# 4549993333.0

# %%
corona_dataset_aggregated.loc["CA"].diff().max()
# Out:
# 5833384803.0

# %%
corona_dataset_aggregated.loc["NJ"].diff().max()
# Out:
# 1411224691.0

# %% [markdown]
# **Task 3.3: find maximum infection rate for all of the states.**

# %%
state = list(corona_dataset_aggregated.index)
max_infection_rate = []
for s in state :
  max_infection_rate.append(corona_dataset_aggregated.loc[s].diff().max())
corona_dataset_aggregated["max_infection_rate"] = max_infection_rate
corona_dataset_aggregated.head()
# Out:
#            death  deathConfirmed  ...  208217690.0  max_infection_rate
# state                             ...
# AK       31486.0         14454.0  ...          NaN         208217690.0
# AL     1038264.0        897681.0  ...          NaN         366277736.0
# AR      601561.0        468918.0  ...          NaN         368537584.0
# AS           0.0             0.0  ...          NaN            444531.0
# AZ     1918434.0       1710791.0  ...          NaN         919026560.0
#
# [5 rows x 23 columns]

# %% [markdown]
# **Task 3.4: create a new dataframe with only needed column.**

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])
corona_data.head()
# Out:
#        max_infection_rate
# state
# AK            208217690.0
# AL            366277736.0
# AR            368537584.0
# AS               444531.0
# AZ            919026560.0

# %% [markdown]
# **Task 4:**

# %%
corona_dataset_aggregated.corr()
# Out:
#                                      death  ...  max_infection_rate
# death                             1.000000  ...            0.902422
# deathConfirmed                    0.411871  ...            0.241854
# deathIncrease                     0.930848  ...            0.938317
# deathProbable                     0.340940  ...            0.125852
# hospitalized                      0.295318  ...            0.196856
# hospitalizedCumulative            0.295318  ...            0.196856
# hospitalizedCurrently             0.878225  ...            0.931408
# hospitalizedIncrease              0.258071  ...            0.168048
# positive                          0.857181  ...            0.929520
# positiveCasesViral                0.632529  ...            0.755977
# positiveIncrease                  0.827902  ...            0.922834
# positiveScore                          NaN  ...                 NaN
# positiveTestsAntibody             0.310993  ...            0.259540
# ...

# %% [markdown]
# **Task 5:**

# %% [markdown]
# **visualization of the results**

# %%
corona_dataset_aggregated.head()
# Out:
#            death  deathConfirmed  ...  208217690.0  max_infection_rate
# state                             ...
# AK       31486.0         14454.0  ...          NaN         208217690.0
# AL     1038264.0        897681.0  ...          NaN         366277736.0
# AR      601561.0        468918.0  ...          NaN         368537584.0
# AS           0.0             0.0  ...          NaN            444531.0
# AZ     1918434.0       1710791.0  ...          NaN         919026560.0
#
# [5 rows x 23 columns]

# %% [markdown]
# **Task 5.1: Plotting totalTestResults vs maximum infection rate**

# %%
x = corona_dataset_aggregated["totalTestResults"]
y = corona_dataset_aggregated["max_infection_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
